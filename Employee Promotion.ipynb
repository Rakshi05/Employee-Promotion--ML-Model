# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('employee_promotion.csv')

# %%
#!pip install seaborn

# %%
#!pip install matplotlib

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# awards_won                 0
# avg_training_score      2560
# is_promoted                0
# dtype: int64

# %%
b=df[df['previous_year_rating'].isnull()]
b
# Out:
#        employee_id         department     region   education gender  \
# 10           29934         Technology  region_23         NaN      m
# 23           71177        Procurement   region_5  Bachelor's      m
# 29           74759  Sales & Marketing   region_4  Bachelor's      m
# 56           45709  Sales & Marketing  region_31  Bachelor's      f
# 58           26599  Sales & Marketing  region_16  Bachelor's      m
# ...            ...                ...        ...         ...    ...
# 54703        74615                R&D  region_31  Bachelor's      m
# 54734        11685         Operations  region_15  Bachelor's      m
# 54746        10546            Finance   region_6  Bachelor's      m
# 54773        37919            Finance   region_2  Bachelor's      m
# 54801        12431         Technology  region_26  Bachelor's      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 10               sourcing                1   30                   NaN
# ...

# %%
b['is_promoted'].value_counts()
# Out:
# 0    3785
# 1     339
# Name: is_promoted, dtype: int64

# %%
c=df[df['avg_training_score'].isnull()]
c
# Out:
#        employee_id         department     region         education gender  \
# 31           58536            Finance  region_31        Bachelor's      m
# 67           16502  Sales & Marketing  region_22        Bachelor's      m
# 128          42068         Operations   region_1  Master's & above      m
# 159          30106  Sales & Marketing  region_16        Bachelor's      f
# 166           4134  Sales & Marketing  region_16        Bachelor's      f
# ...            ...                ...        ...               ...    ...
# 54701        23170  Sales & Marketing  region_28  Master's & above      m
# 54736        38707         Operations  region_31        Bachelor's      m
# 54746        10546            Finance   region_6        Bachelor's      m
# 54773        37919            Finance   region_2        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
c['is_promoted'].value_counts()
# Out:
# 0    2383
# 1     177
# Name: is_promoted, dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [employee_id, department, region, education, gender, recruitment_channel, no_of_trainings, age, previous_year_rating, length_of_service, awards_won, avg_training_score, is_promoted]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  awards_won            54808 non-null  int64
#  11  avg_training_score    52248 non-null  float64
#  12  is_promoted           54808 non-null  int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 5.4+ MB

# %%
df.shape
# Out:
# (54808, 13)

# %%
df.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service    awards_won  avg_training_score   is_promoted
# count       54808.000000  54808.000000        52248.000000  54808.000000
# mean            5.865512      0.023172           63.712238      0.085170
# std             4.265094      0.150450           13.521910      0.279137
# ...

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'awards_won', 'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
df['is_promoted'].value_counts()
# Out:
# 0    50140
# 1     4668
# Name: is_promoted, dtype: int64

# %%
df.corr()
# Out:
#                       employee_id  no_of_trainings       age  \
# employee_id              1.000000        -0.005121  0.000437
# no_of_trainings         -0.005121         1.000000 -0.081278
# age                      0.000437        -0.081278  1.000000
# previous_year_rating     0.004533        -0.063126  0.006008
# length_of_service        0.001274        -0.057275  0.657111
# awards_won               0.008420        -0.007628 -0.008169
# avg_training_score      -0.000661         0.044430 -0.049500
# is_promoted              0.001206        -0.024896 -0.017166
#
#                       previous_year_rating  length_of_service  awards_won  \
# employee_id                       0.004533           0.001274    0.008420
# no_of_trainings                  -0.063126          -0.057275   -0.007628
# age                               0.006008           0.657111   -0.008169
# previous_year_rating              1.000000           0.000253    0.027738
# ...

# %%
sns.pairplot(df.corr())

# %%
a=df['previous_year_rating'].value_counts()
a
# Out:
# 3.0    18618
# 5.0    11741
# 4.0     9877
# 1.0     6223
# 2.0     4225
# Name: previous_year_rating, dtype: int64

# %%
df['previous_year_rating'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
a.plot(kind='pie',autopct="%0.2f")
# Out:
# <AxesSubplot:ylabel='previous_year_rating'>

# %%
sns.barplot(x="previous_year_rating", y="awards_won",hue="is_promoted", data=df)
# Out:
# <AxesSubplot:xlabel='previous_year_rating', ylabel='awards_won'>

# %%
sns.barplot(x="avg_training_score", y="awards_won",hue="is_promoted", data=df)
# Out:
# <AxesSubplot:xlabel='avg_training_score', ylabel='awards_won'>

# %%
sns.barplot(x="previous_year_rating", y="avg_training_score",hue="is_promoted", data=df)
# Out:
# <AxesSubplot:xlabel='previous_year_rating', ylabel='avg_training_score'>

# %%
sns.barplot(y="awards_won", x="is_promoted", data=df)
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='awards_won'>

# %%
sns.barplot(y="previous_year_rating", x="is_promoted", data=df)
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='previous_year_rating'>

# %%
sns.barplot(y="avg_training_score", x="is_promoted", data=df)
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='avg_training_score'>

# %%
sns.barplot(y="length_of_service", x="is_promoted", data=df)
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='length_of_service'>

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted
# 0                  8           0                49.0            0
# ...

# %%
sns.barplot(y="no_of_trainings", x="is_promoted", data=df)
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='no_of_trainings'>

# %%
sns.barplot(y="age", x="is_promoted", data=df)
# Out:
# <AxesSubplot:xlabel='is_promoted', ylabel='age'>

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head(1)
# Out:
#    employee_id         department    region         education gender  \
# 0        65438  Sales & Marketing  region_7  Master's & above      f
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted
# 0                  8           0                49.0            0

# %%
df1 = df.drop(['employee_id','department','region','recruitment_channel'], axis = 1)
df1
# Out:
#               education gender  no_of_trainings  age  previous_year_rating  \
# 0      Master's & above      f                1   35                   5.0
# 1            Bachelor's      m                1   30                   5.0
# 2            Bachelor's      m                1   34                   3.0
# 3            Bachelor's      m                2   39                   1.0
# 4            Bachelor's      m                1   45                   3.0
# ...                 ...    ...              ...  ...                   ...
# 54803        Bachelor's      m                1   48                   3.0
# 54804  Master's & above      f                1   37                   2.0
# 54805        Bachelor's      m                1   27                   5.0
# 54806               NaN      m                1   29                   1.0
# 54807        Bachelor's      m                1   27                   1.0
#
# ...

# %%
df1.isnull().sum()
# Out:
# education               2409
# gender                     0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# awards_won                 0
# avg_training_score      2560
# is_promoted                0
# dtype: int64

# %%
df2=df1.dropna()
df2
# Out:
#               education gender  no_of_trainings  age  previous_year_rating  \
# 0      Master's & above      f                1   35                   5.0
# 1            Bachelor's      m                1   30                   5.0
# 2            Bachelor's      m                1   34                   3.0
# 3            Bachelor's      m                2   39                   1.0
# 4            Bachelor's      m                1   45                   3.0
# ...                 ...    ...              ...  ...                   ...
# 54802        Bachelor's      m                2   31                   1.0
# 54803        Bachelor's      m                1   48                   3.0
# 54804  Master's & above      f                1   37                   2.0
# 54805        Bachelor's      m                1   27                   5.0
# 54807        Bachelor's      m                1   27                   1.0
#
# ...

# %%
df2.isnull().sum()
# Out:
# education               0
# gender                  0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# awards_won              0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
df2['is_promoted'].value_counts()
# Out:
# 0    42309
# 1     4071
# Name: is_promoted, dtype: int64

# %%
df["is_promoted"].value_counts()
# Out:
# 0    50140
# 1     4668
# Name: is_promoted, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df2['gender'] = le.fit_transform(df2['gender'])
# Out:
# C:\Users\lavanya\AppData\Local\Temp\ipykernel_21516\2983753961.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['gender'] = le.fit_transform(df2['gender'])

# %%
df2
# Out:
#               education  gender  no_of_trainings  age  previous_year_rating  \
# 0      Master's & above       0                1   35                   5.0
# 1            Bachelor's       1                1   30                   5.0
# 2            Bachelor's       1                1   34                   3.0
# 3            Bachelor's       1                2   39                   1.0
# 4            Bachelor's       1                1   45                   3.0
# ...                 ...     ...              ...  ...                   ...
# 54802        Bachelor's       1                2   31                   1.0
# 54803        Bachelor's       1                1   48                   3.0
# 54804  Master's & above       0                1   37                   2.0
# 54805        Bachelor's       1                1   27                   5.0
# 54807        Bachelor's       1                1   27                   1.0
#
# ...

# %%
df3=pd.get_dummies(df2)
df3
# Out:
#        gender  no_of_trainings  age  previous_year_rating  length_of_service  \
# 0           0                1   35                   5.0                  8
# 1           1                1   30                   5.0                  4
# 2           1                1   34                   3.0                  7
# 3           1                2   39                   1.0                 10
# 4           1                1   45                   3.0                  2
# ...       ...              ...  ...                   ...                ...
# 54802       1                2   31                   1.0                  2
# 54803       1                1   48                   3.0                 17
# 54804       0                1   37                   2.0                  6
# 54805       1                1   27                   5.0                  3
# 54807       1                1   27                   1.0                  5
#
# ...

# %%
df3.corr()
# Out:
#                               gender  no_of_trainings       age  \
# gender                      1.000000         0.084726 -0.004381
# no_of_trainings             0.084726         1.000000 -0.084901
# age                        -0.004381        -0.084901  1.000000
# previous_year_rating       -0.022725        -0.064414  0.004825
# length_of_service          -0.012415        -0.056410  0.620466
# awards_won                  0.002106        -0.009460 -0.012328
# avg_training_score         -0.016947         0.043313 -0.067184
# is_promoted                -0.012980        -0.025955 -0.024067
# education_Bachelor's        0.029059         0.036575 -0.305533
# education_Below Secondary  -0.012017         0.004633 -0.145899
# education_Master's & above -0.026825        -0.037819  0.337940
#
#                             previous_year_rating  length_of_service  \
# gender                                 -0.022725          -0.012415
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df3.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df3.corr()['is_promoted']
# Out:
# gender                       -0.012980
# no_of_trainings              -0.025955
# age                          -0.024067
# previous_year_rating          0.160455
# length_of_service            -0.015027
# awards_won                    0.199343
# avg_training_score            0.182750
# is_promoted                   1.000000
# education_Bachelor's         -0.026464
# education_Below Secondary    -0.002237
# education_Master's & above    0.027136
# Name: is_promoted, dtype: float64

# %%
X = df3.drop("is_promoted", axis=1)
y = df3['is_promoted']

# %%
X
# Out:
#        gender  no_of_trainings  age  previous_year_rating  length_of_service  \
# 0           0                1   35                   5.0                  8
# 1           1                1   30                   5.0                  4
# 2           1                1   34                   3.0                  7
# 3           1                2   39                   1.0                 10
# 4           1                1   45                   3.0                  2
# ...       ...              ...  ...                   ...                ...
# 54802       1                2   31                   1.0                  2
# 54803       1                1   48                   3.0                 17
# 54804       0                1   37                   2.0                  6
# 54805       1                1   27                   5.0                  3
# 54807       1                1   27                   1.0                  5
#
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 54802    0
# 54803    0
# 54804    0
# 54805    0
# 54807    0
# Name: is_promoted, Length: 46380, dtype: int64

# %%
# !pip3 install --upgrade pip
# Out:
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# ...

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
x_resampled, y_resampled = SMOTE().fit_resample(X,y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x_resampled, y_resampled,train_size=0.75,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\Users\lavanya\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
y_pred = model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.7194043961238478

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[7863, 2598],
#        [3338, 7356]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.75      0.73     10461
#            1       0.74      0.69      0.71     10694
#
#     accuracy                           0.72     21155
#    macro avg       0.72      0.72      0.72     21155
# weighted avg       0.72      0.72      0.72     21155

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
#!pip install xgboost
# Out:
# ...
#      ------------------------------------- 125.4/125.4 MB 11.7 MB/s eta 0:00:00
# ...

# %%
models = []
models.append(('LR', LogisticRegression(max_iter=500)))
models.append(('XGBoost', XGBClassifier()))
models.append(("RF", RandomForestClassifier()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('NB', GaussianNB()))
#models.append(('SVM', SVC()))

# %%
results = []
names = []
scoring = 'accuracy'
for name, model in models:
    kfold = KFold(n_splits= 10)
    cv_results = cross_val_score(model, X, y, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = '%s %f (%f)' % (name,cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# C:\Users\lavanya\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\lavanya\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
df3
# Out:
#        gender  no_of_trainings  age  previous_year_rating  length_of_service  \
# 0           0                1   35                   5.0                  8
# 1           1                1   30                   5.0                  4
# 2           1                1   34                   3.0                  7
# 3           1                2   39                   1.0                 10
# 4           1                1   45                   3.0                  2
# ...       ...              ...  ...                   ...                ...
# 54802       1                2   31                   1.0                  2
# 54803       1                1   48                   3.0                 17
# 54804       0                1   37                   2.0                  6
# 54805       1                1   27                   5.0                  3
# 54807       1                1   27                   1.0                  5
#
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense
